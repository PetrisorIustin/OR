# %%
from gurobipy import *

# %%
try:

    # Create a new model
    m = Model("mip1")

    # Create variables
    x = m.addVar(vtype=GRB.BINARY, name="x")
    y = m.addVar(vtype=GRB.BINARY, name="y")
    z = m.addVar(vtype=GRB.BINARY, name="z")

    # Set objective
    m.setObjective(x + y + 2 * z, GRB.MAXIMIZE)

    # Add constraint: x + 2 y + 3 z <= 4
    m.addConstr(x + 2 * y + 3 * z <= 4, "c0")

    # Add constraint: x + y >= 1
    m.addConstr(x + y >= 1, "c1")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 2 rows, 3 columns and 5 nonzeros
# Variable types: 0 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 2.0000000
# Presolve removed 2 rows and 3 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 3 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# x 1
# y 0
# z 1
# Obj: 3

# %%
try:

    # Create a new model
    m = Model("mip2")

    # Create variables
    x1 = m.addVar(vtype=GRB.CONTINUOUS, name="x1")
    x2 = m.addVar(vtype=GRB.CONTINUOUS, name="x2")

    # Set objective
    m.setObjective(2*x1 + 3*x2, GRB.MINIMIZE)

    # Add constraint: x + 2 y + 3 z <= 4
    m.addConstr(3*x1 + 2*x2 == 14, "c0")

    # Add constraint: x + y >= 1
    m.addConstr(2*x1 - 4*x2 >= 2, "c1")
    m.addConstr(4*x1 + 3*x2 <= 19, "c2")
    
    m.addConstr(x1 >= 0, "c3")
    m.addConstr(x2 >= 0, "c4")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 5 rows, 2 columns and 8 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+01]
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3333333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds
# Optimal objective  9.333333333e+00
# x1 4.66667
# x2 0
# Obj: 9.33333

# %%
try:

    # Create a new model
    m = Model("mip2")

    # Create variables
    x1 = m.addVar(vtype=GRB.CONTINUOUS, name="x1")
    x2 = m.addVar(vtype=GRB.CONTINUOUS, name="x2")
    x3 = m.addVar(vtype=GRB.CONTINUOUS, name="x3")
    x4 = m.addVar(vtype=GRB.CONTINUOUS, name="x4")

    # Set objective
    m.setObjective(x1 + 2*x2 + x3, GRB.MINIMIZE)

    # Add constraint: x + 2 y + 3 z <= 4
    m.addConstr(2*x1 + x2 + x3 == 30, "c0")
    m.addConstr(-x1 + x2 + 2*x4 == 12, "c1")

    m.addConstr(x1 >= 0, "c2")
    m.addConstr(x2 >= 0, "c3")
    m.addConstr(x3 >= 0, "c4")
    m.addConstr(x4 >= 0, "c5")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Optimize a model with 6 rows, 4 columns and 10 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 3e+01]
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective  1.500000000e+01
# x1 15
# x2 0
# x3 0
# x4 13.5
# Obj: 15

# %%
try:

    # Create a new model
    m = Model("c)")

    # Create variables
    x1 = m.addVar(vtype=GRB.CONTINUOUS, name="x1")
    x2 = m.addVar(vtype=GRB.CONTINUOUS, name="x2")
    x3 = m.addVar(vtype=GRB.CONTINUOUS, name="x3")
    x4 = m.addVar(vtype=GRB.CONTINUOUS, name="x4")

    # Set objective
    m.setObjective(-3*x1 + x2 + 3*x3 - x4, GRB.MINIMIZE)

    # Add constraint: x + 2 y + 3 z <= 4
    m.addConstr(x1 + 2*x2 - x3 + x4 == 0, "c0")
    m.addConstr(2*x1 - 2*x2 + 3*x3 + 3*x4 == 9, "c1")
    m.addConstr(x1 - x2 + 2*x3 - x4 == 6, "c2")

    m.addConstr(x1 >= 0, "c3")
    m.addConstr(x2 >= 0, "c4")
    m.addConstr(x3 >= 0, "c5")
    m.addConstr(x3 >= 0, "c6")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Optimize a model with 7 rows, 4 columns and 16 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 9e+00]
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective  7.000000000e+00
# x1 1
# x2 1
# x3 3
# x4 0
# Obj: 7

# %%
try:

    # Create a new model
    m = Model("mip2")

    # Create variables
    x1 = m.addVar(vtype=GRB.CONTINUOUS, name="x1")
    x2 = m.addVar(vtype=GRB.CONTINUOUS, name="x2")
    x3 = m.addVar(vtype=GRB.CONTINUOUS, name="x3")
    x4 = m.addVar(vtype=GRB.CONTINUOUS, name="x4")
    x5 = m.addVar(vtype=GRB.CONTINUOUS, name="x5")
    x6 = m.addVar(vtype=GRB.CONTINUOUS, name="x6")

    m.setObjective(-2*x1 - x2, GRB.MINIMIZE)

    m.addConstr(2*x1 + x2 + 2*x3 == 4, "c0")
    m.addConstr(2*x1 + 3*x2 + x4 == 3, "c1")
    m.addConstr(4*x1 + x2 + 3*x5 == 5, "c2")
    m.addConstr(x1 + 5*x2 + x6 == 1, "c3")
    
    m.addConstr(x1 >= 0, "c4")
    m.addConstr(x2 >= 0, "c5")
    m.addConstr(x3 >= 0, "c6")
    m.addConstr(x4 >= 0, "c7")
    m.addConstr(x5 >= 0, "c8")
    m.addConstr(x6 >= 0, "c9")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Optimize a model with 10 rows, 6 columns and 18 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 10 rows and 6 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -2.000000000e+00
# x1 1
# x2 0
# x3 1
# x4 1
# x5 0.333333
# x6 0
# Obj: -2

# %%
try:

    # Create a new model
    m = Model("mip2")

    # Create variables
    x1 = m.addVar(vtype=GRB.INTEGER, name="x1")
    x2 = m.addVar(vtype=GRB.INTEGER, name="x2")
    x3 = m.addVar(vtype=GRB.INTEGER, name="x3")

    m.setObjective(x1 - x2 + 2*x3, GRB.MAXIMIZE)

    m.addConstr(x1 - 2*x2 + 2*x3 <= 6, "c0")
    m.addConstr(x1 + x2 + 2*x3 <= 8, "c1")
    
    m.addConstr(x1 >= 0, "c4")
    m.addConstr(x2 >= 0, "c5")
    m.addConstr(x3 >= 0, "c6")

    # Optimize model
    m.optimize()

    for v in m.getVars():
        print('%s %g' % (v.varName, v.x))

    print('Obj: %g' % m.objVal)

except GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 8e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# x1 7
# x2 1
# x3 -0
# Obj: 6

# %%
m = Model("mip2")

# Create variables
x1 = m.addVar(vtype=GRB.INTEGER, name="x1")
x2 = m.addVar(vtype=GRB.INTEGER, name="x2")

m.setObjective(2*x1 + x2, GRB.MAXIMIZE)

m.addConstr(-x1 + x2 <= 0, "c0")
m.addConstr(6*x1 + 2*x2  <= 21, "c1")

m.addConstr(x1 >= 0, "c4")
m.addConstr(x2 >= 0, "c5")

# Optimize model
m.optimize()

for v in m.getVars():
    print('%s %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 2 columns, 4 nonzeros
# Variable types: 0 continuous, 2 integer (0 binary)
#
# Root relaxation: infeasible, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# x1 3
# x2 1
# Obj: 7

# %%
m = Model("mip2")

# Create variables
x1 = m.addVar(vtype=GRB.INTEGER, name="x1")
x2 = m.addVar(vtype=GRB.INTEGER, name="x2")
x3 = m.addVar(vtype=GRB.INTEGER, name="x3")
x4 = m.addVar(vtype=GRB.INTEGER, name="x4")

m.setObjective(x1 + x2 + x3 + 2*x4, GRB.MAXIMIZE)

m.addConstr(x1 + 2*x2 + x3 - x4 <= 8, "c0")
m.addConstr(x1 + 2*x2 + 2*x4  <= 7, "c1")
m.addConstr(4*x1 + x2 + 3*x3 <= 8, "c1")

m.addConstr(x1 >= 0, "c4")
m.addConstr(x2 >= 0, "c5")
m.addConstr(x3 >= 0, "c6")
m.addConstr(x4 >= 0, "c7")

# Optimize model
m.optimize()

for v in m.getVars():
    print('%s %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 7 rows, 4 columns and 14 nonzeros
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 8e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 8 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# x1 -0
# x2 -0
# x3 2
# x4 3
# Obj: 8
